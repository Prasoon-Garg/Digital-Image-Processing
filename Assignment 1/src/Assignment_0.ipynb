# %%
import numpy as np
import cv2

# %%
img1 = cv2.imread('./images/eiifel.webp')
img2 = cv2.imread('./images/liberty.webp')
img3 = cv2.imread('./images/pyramid.webp')
img4 = cv2.imread('./images/taj_mahal.webp')

# %%
print("Eiffel Tower")
print(img1)

print()
print()
print("Statue of Liberty")
print(img2)

print()
print()
print("Pyramids")
print(img3)

print()
print()
print("Taj Mahal")
print(img4)
# Out:
# Eiffel Tower
# [[[221 217 213]
#   [217 214 210]
#   [215 212 208]
#   ...
#   [204 127   3]
#   [204 127   3]
#   [205 129   4]]
#
#  [[221 217 213]
#   [217 214 210]
#   [215 212 208]
#   ...
#   [204 127   3]
#   [204 127   3]
#   [204 127   3]]
#
#  [[221 217 213]
#   [217 214 210]
#   [215 212 208]
#   ...
#   [202 128   3]
#   [202 128   3]
#   [202 128   3]]
#
#  ...
#
#  [[  8   7  10]
#   [  0   2   4]
#   [ 10  14  16]
#   ...
#   [ 44  46  60]
#   [ 29  31  45]
#   [ 21  23  36]]
#
#  [[ 25  22  25]
#   [  7   6   9]
#   [  3   7   9]
#   ...
#   [ 10  13  24]
#   [ 31  34  45]
#   [ 49  52  63]]
#
#  [[ 63  57  63]
#   [  9   8  11]
#   [  0   2   4]
#   ...
#   [ 22  25  36]
#   [ 30  33  44]
#   [ 66  67  78]]]
#
#
# Statue of Liberty
# [[[153 137 135]
#   [156 141 139]
#   [160 144 142]
#   ...
#   [166 153 151]
#   [165 150 148]
#   [164 149 147]]
#
#  [[156 141 139]
#   [158 143 141]
#   [162 147 145]
#   ...
#   [166 153 151]
#   [164 149 147]
#   [163 148 146]]
#
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(1)

plt.subplot(221)
plt.axis("off")
plt.imshow(img1)

plt.subplot(222)
plt.axis("off")
plt.imshow(img2)

plt.subplot(223)
plt.axis("off")
plt.imshow(img3)

plt.subplot(224)
plt.axis("off")
plt.imshow(img4)

plt.show()

# %%
mod_img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
mod_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
mod_img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
mod_img4 = cv2.cvtColor(img4, cv2.COLOR_BGR2RGB)

# %%
plt.figure(1)

plt.subplot(221)
plt.axis("off")
plt.imshow(mod_img1)


plt.subplot(222)
plt.axis("off")
plt.imshow(mod_img2)

plt.subplot(223)
plt.axis("off")
plt.imshow(mod_img3)

plt.subplot(224)
plt.axis("off")
plt.imshow(mod_img4)

plt.show()

# %%
cv2.imwrite('modified_eiifel.jpg', cv2.cvtColor(mod_img1, cv2.COLOR_RGB2BGR))
cv2.imwrite('modified_liberty.jpg',cv2.cvtColor(mod_img2, cv2.COLOR_RGB2BGR))
cv2.imwrite('modified_pyramids.jpg', cv2.cvtColor(mod_img3, cv2.COLOR_RGB2BGR))
cv2.imwrite('modified_taj_mahal.jpg', cv2.cvtColor(mod_img4, cv2.COLOR_RGB2BGR))
# Out:
# True

# %%
image = cv2.imread('./modified_pyramids.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray_image = 0.2989*image[:,:,0]+0.5870*image[:,:,1]+0.1140*image[:,:,2]

# %%
plt.figure()

plt.subplot(121)
plt.axis("off")
plt.imshow(image);

plt.subplot(122)
plt.axis("off")
plt.imshow(gray_image, cmap='gray')

plt.show()

# %%
img1.shape
# Out:
# (225, 339, 3)

# %%
R_low = mod_img4[:,:,0].min()
R_high = mod_img4[:,:,0].max()

G_low = mod_img4[:,:,1].min()
G_high = mod_img4[:,:,1].max()

B_low = mod_img4[:,:,2].min()
B_high = mod_img4[:,:,2].max()

# %%
print("Red Color intensity ->",R_low, "-" ,R_high)
print()
print("Green Color intensity ->",G_low, "-" ,G_high)
print()
print("Blue Color intensity ->",B_low, "-" ,B_high)
print()
# Out:
# Red Color intensity -> 0 - 255
#
# Green Color intensity -> 0 - 251
#
# Blue Color intensity -> 0 - 234

# %%
a = mod_img4.shape
row = s[0]
col = s[1]

# %%
S=0
for i in range(row):
      for j in range(col):
          S = S+mod_img4[i,j,0]+mod_img4[i,j,1]+mod_img4[i,j,2];

Brightness = S/(row*col*3);

# %%
print(Brightness)
# Out:
# 84.35792362310497

# %% [markdown]
# ### We infer from the above data that the max red, green and blue color intensity of the TAJ MAHAL image is 255, 251, 234 respectively and from the RGB iintensity of each pixel of the image we can calculate the
